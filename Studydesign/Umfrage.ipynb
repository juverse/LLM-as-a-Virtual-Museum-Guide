# %% [markdown]
# ## Umfrage zur Nutzung
#
# virtuwander:
#
# (a) Ratings for Multi-modal Feedback Design
# Q1 - It was focused.
# Q2 - It was easy to understand.
# Q3 - It was helpful.
# Q4 - It was fun to use.
# Q5 - It was novel.
#
# (b) Ratings for VirtuWander
# Engagement
# Q1 - It was helpful to use this tool.
# Q2 - It was fun to use this tool.
# Q3 - I was likely to use this tool.
# Q4 - It was in control.
#
# Usability
#
# Q5 - It was easy to use this tool.
# Q6 - It was natural to use this tool.
# Q7 - It was tailored to my personal interests.
# Q8 - It was easy to learn to use this tool.
#
# Workload
#
# Q9 - I did not need much mental load.
# Q10 - I did not need much physical load.
#
# Experience
# Q11 - It was comfortable to use this tool.
# Q12 - I felt immersed in the environment.
# Q13 - It was easy to know where I was.

# %% [markdown]
# Umfrage:
# culture AI
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Umfrage:
# nach jeder Modi
